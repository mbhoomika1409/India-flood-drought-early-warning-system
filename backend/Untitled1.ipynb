# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. CREATE DATASET

data = {
    'Customer_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 103],

    'Name': [
        'Rahul', 'Priya', 'Amit', 'Sneha', 'Arun',
        'Kiran', 'Meena', 'Ravi', 'Anita', 'Vijay', 'Amit'
    ],

    'Age': [
        25, 30, np.nan, 28, 150,
        35, 29, np.nan, 42, 31, 28
    ],

    'Gender': [
        'Male', 'Female', 'Male', 'Female', 'Male',
        'Female', 'Female', 'Male', 'Female', 'Male', 'Male'
    ],

    'City': [
        'Bangalore', 'Bengaluru', 'Mysore', 'Mysore', 'Hubli',
        'Bangalore', 'Bengaluru', 'Mysore', 'Mysuru', 'Hubli', 'Mysore'
    ],

    'Income': [
        45000, 55000, 40000, 60000, 50000,
        48000, 52000, 47000, 1000000, np.nan, 40000
    ],

    'Purchased': [
        'Yes', 'No', 'Yes', 'Yes', 'No',
        'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes'
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the original dataset
print("\nORIGINAL DATASET")
print(df)
# Out:
# ORIGINAL DATASET
#     Customer_ID   Name    Age  Gender       City     Income Purchased
# 0           101  Rahul   25.0    Male  Bangalore    45000.0       Yes
# 1           102  Priya   30.0  Female  Bengaluru    55000.0        No
# 2           103   Amit    NaN    Male     Mysore    40000.0       Yes
# 3           104  Sneha   28.0  Female     Mysore    60000.0       Yes
# 4           105   Arun  150.0    Male      Hubli    50000.0        No
# 5           106  Kiran   35.0  Female  Bangalore    48000.0       Yes
# 6           107  Meena   29.0  Female  Bengaluru    52000.0        No
# 7           108   Ravi    NaN    Male     Mysore    47000.0       Yes
# 8           109  Anita   42.0  Female     Mysuru  1000000.0        No
# 9           110  Vijay   31.0    Male      Hubli        NaN       Yes
# 10          103   Amit   28.0    Male     Mysore    40000.0       Yes

# %%
# 2. DATASET INFORMATION
print("\nDATASET INFORMATION")
df.info()
print("\nSTATISTICAL SUMMARY")
print(df.describe())
# Out:
# DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer_ID  11 non-null     int64
#  1   Name         11 non-null     object
#  2   Age          9 non-null      float64
#  3   Gender       11 non-null     object
#  4   City         11 non-null     object
#  5   Income       10 non-null     float64
#  6   Purchased    11 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 748.0+ bytes
#
# STATISTICAL SUMMARY
#        Customer_ID         Age          Income
# count    11.000000    9.000000       10.000000
# mean    105.272727   44.222222   143700.000000
# std       2.969542   39.974297   300937.442743
# min     101.000000   25.000000    40000.000000
# 25%     103.000000   28.000000    45500.000000
# 50%     105.000000   30.000000    49000.000000
# ...

# %%
# 3. MISSING VALUE DETECTION
print("\nMISSING VALUES")
print(df.isnull().sum())
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("\nMISSING VALUE PERCENTAGE")
print(missing_percentage)
# Out:
# MISSING VALUES
# Customer_ID    0
# Name           0
# Age            2
# Gender         0
# City           0
# Income         1
# Purchased      0
# dtype: int64
#
# MISSING VALUE PERCENTAGE
# Customer_ID     0.000000
# Name            0.000000
# Age            18.181818
# Gender          0.000000
# City            0.000000
# Income          9.090909
# Purchased       0.000000
# dtype: float64
